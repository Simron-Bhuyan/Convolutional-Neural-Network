# %%
import tensorflow as tf

from tensorflow.keras import datasets,layers,models
import matplotlib.pyplot as plt

# %%
(train_images, train_labels), (test_images, test_labels)= datasets.cifar10.load_data()

#Normalize pixel vales to be between 0 and 1
train_images, test_images = train_images / 255.0, test_images / 255.0
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 4s 0us/step

# %%
model = models.Sequential()
model.add(layers.Conv2D(32,(3,3), activation='relu', input_shape=(32, 32, 3)))
model.add(layers.MaxPooling2D((2,2)))
model.add(layers.Conv2D(64,(3,3), activation='relu'))
model.add(layers.MaxPooling2D((2,2)))
model.add(layers.Conv2D(64,(3,3), activation='relu'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 32)        896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 64)          36928
# =================================================================
# Total params: 56,320
# Trainable params: 56,320
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(10))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 32)        896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 64)          36928
# _________________________________________________________________
# flatten (Flatten)            (None, 1024)              0
# _________________________________________________________________
# dense (Dense)                (None, 64)                65600
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                650
# =================================================================
# Total params: 122,570
# Trainable params: 122,570
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

history = model.fit(train_images, train_labels, epochs=10,
                    validation_data=(test_images, test_labels))
# Out:
# Epoch 1/10
# 1563/1563 [==============================] - 67s 43ms/step - loss: 1.7100 - accuracy: 0.3645 - val_loss: 1.2103 - val_accuracy: 0.5653
# Epoch 2/10
# 1563/1563 [==============================] - 66s 42ms/step - loss: 1.1767 - accuracy: 0.5801 - val_loss: 1.0435 - val_accuracy: 0.6283
# Epoch 3/10
# 1563/1563 [==============================] - 66s 42ms/step - loss: 1.0034 - accuracy: 0.6498 - val_loss: 0.9536 - val_accuracy: 0.6664
# Epoch 4/10
# 1563/1563 [==============================] - 66s 42ms/step - loss: 0.8870 - accuracy: 0.6909 - val_loss: 0.9301 - val_accuracy: 0.6766
# Epoch 5/10
# 1563/1563 [==============================] - 66s 42ms/step - loss: 0.8129 - accuracy: 0.7128 - val_loss: 0.9321 - val_accuracy: 0.6791
# Epoch 6/10
# 1563/1563 [==============================] - 66s 42ms/step - loss: 0.7498 - accuracy: 0.7345 - val_loss: 0.8560 - val_accuracy: 0.6968
# Epoch 7/10
# 1563/1563 [==============================] - 65s 42ms/step - loss: 0.6924 - accuracy: 0.7571 - val_loss: 0.8617 - val_accuracy: 0.7062
# Epoch 8/10
# 1563/1563 [==============================] - 65s 42ms/step - loss: 0.6431 - accuracy: 0.7747 - val_loss: 0.8503 - val_accuracy: 0.7135
# Epoch 9/10
# 1563/1563 [==============================] - 65s 42ms/step - loss: 0.5928 - accuracy: 0.7925 - val_loss: 0.8630 - val_accuracy: 0.7113
# Epoch 10/10
# 1563/1563 [==============================] - 67s 43ms/step - loss: 0.5615 - accuracy: 0.8018 - val_loss: 0.8630 - val_accuracy: 0.7167

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels, verbose=2)
# Out:
# 313/313 - 4s - loss: 0.8630 - accuracy: 0.7167

# %%
print(test_acc)
# Out:
# 0.71670001745224
